# %%
from analysis.analysis import compute_metrics
from analysis.plot_metrics import plot_metrics

metrics = compute_metrics('data/sample_study/sample.csv')
print('Metrics:', metrics)
plot_metrics('data/sample_study/sample.csv', 'analysis/results/plot.png')
print('Plot written to analysis/results/plot.png')

# %% [markdown]
# ## Validation outputs
#
# **Metrics (analysis/results/metrics.json):**
#
# ```
# {
#   "total": 425,
#   "positives": 125,
#   "negatives": 300,
#   "tp": 124,
#   "tn": 299,
#   "fp": 1,
#   "fn": 1,
#   "sensitivity": 0.992,
#   "sensitivity_ci": [0.956074, 0.998586],
#   "specificity": 0.996667,
#   "specificity_ci": [0.981363, 0.999411]
# }
# ```
#
# **Plot:**
#
# ![Validation plot](analysis/results/plot.png)
#
# **Notes:** This notebook demonstrates the reproducible analysis and links to generated outputs (metrics JSON and plot). To reproduce, run the analysis cells (Python 3.11) and re-run the plotting cell; outputs will be written to `analysis/results/`.
